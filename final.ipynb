# %%
from ultralytics import YOLO
import os 
from IPython.display import display,Image
from IPython import display
display.clear_output()
from PIL import Image
import numpy as np
import cv2

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="OgVdrQ7c3J4qYDRhJT7p")
project = rf.workspace("vincent-workspace").project("13858358")
version = project.version(2)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# Dependency ultralytics==8.0.196 is required but found version=8.3.1, to fix: `pip install ultralytics==8.0.196`
# ...
# Extracting Dataset Version Zip to 13858358-2 in yolov8:: 100%|██████████| 668/668 [00:01<00:00, 482.48it/s]

# %%
# !yolo task=detect mode=train model="C:\\path\\to\\yolov8m.pt" data="C:\Users\VINJAYCAS\Desktop\codeprojects\13858358-2\data.yaml" epochs=20 imgsz=640
# Out:
# Ultralytics 8.3.1 🚀 Python-3.11.4 torch-2.4.1+cpu CPU (11th Gen Intel Core(TM) i5-11400F 2.60GHz)
# ...
